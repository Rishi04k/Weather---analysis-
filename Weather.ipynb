# %% [markdown]
# ## Importing Libraries ##

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing data set 

df = pd.read_csv("Project 1 - Weather Dataset.csv")
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df                            # Complete Dataset
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.shape                        # No. of rows and columns
# Out:
# (8784, 8)

# %%
df.dtypes                        # Datatypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])               # Converting Date/time datatype
df.dtypes
# Out:
# Date/Time           datetime64[ns]
# Temp_C                     float64
# Dew Point Temp_C           float64
# Rel Hum_%                    int64
# Wind Speed_km/h              int64
# Visibility_km              float64
# Press_kPa                  float64
# Weather                     object
# dtype: object

# %%
df['Weather'].unique()                        # Unique values
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df.nunique()                    # Total number of unique values
# Out:
# Date/Time           8784
# Temprature_C         533
# Dew Point Temp_C     489
# Humidity_%            83
# Wind Speed_km/h       34
# Visibility_km         24
# Pressure_kPa         518
# Weather               50
# dtype: int64

# %% [raw]
# - By this command we can find any unique value from the columns ..

# %%
df.count()                         # Checking for the null values
# Out:
# Date/Time           8784
# Temprature_C        8784
# Dew Point Temp_C    8784
# Humidity_%          8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Pressure_kPa        8784
# Weather             8784
# dtype: int64

# %%
df['Weather'].value_counts()                            # No of values of each
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %% [markdown]
# ### 1. Weather is clear

# %%
df.groupby('Weather').get_group('Clear')
# Out:
#                Date/Time  Temprature_C  Dew Point Temp_C  Humidity_%  \
# 67   2012-01-03 19:00:00         -16.9             -24.8          50
# 114  2012-01-05 18:00:00          -7.1             -14.4          56
# 115  2012-01-05 19:00:00          -9.2             -15.4          61
# 116  2012-01-05 20:00:00          -9.8             -15.7          62
# 117  2012-01-05 21:00:00          -9.0             -14.8          63
# ...                  ...           ...               ...         ...
# 8646 2012-12-26 06:00:00         -13.4             -14.8          89
# 8698 2012-12-28 10:00:00          -6.1              -8.6          82
# 8713 2012-12-29 01:00:00         -11.9             -13.6          87
# 8714 2012-12-29 02:00:00         -11.8             -13.1          90
# 8756 2012-12-30 20:00:00         -13.8             -16.5          80
#
#       Wind Speed_km/h  Visibility_km  Pressure_kPa Weather
# 67                 24           25.0        101.74   Clear
# ...

# %% [markdown]
# ### 2. When wind speed is exactly 4 km/h..

# %%
df[df['Wind Speed_km/h'] == 4]
# Out:
#                Date/Time  Temprature_C  Dew Point Temp_C  Humidity_%  \
# 0    2012-01-01 00:00:00          -1.8              -3.9          86
# 1    2012-01-01 01:00:00          -1.8              -3.7          87
# 96   2012-01-05 00:00:00          -8.8             -11.7          79
# 101  2012-01-05 05:00:00          -7.0              -9.5          82
# 146  2012-01-07 02:00:00          -8.1             -11.1          79
# ...                  ...           ...               ...         ...
# 8768 2012-12-31 08:00:00          -8.6             -10.3          87
# 8769 2012-12-31 09:00:00          -8.1              -9.6          89
# 8770 2012-12-31 10:00:00          -7.4              -8.9          89
# 8772 2012-12-31 12:00:00          -5.8              -7.5          88
# 8773 2012-12-31 13:00:00          -4.6              -6.6          86
#
#       Wind Speed_km/h  Visibility_km  Pressure_kPa       Weather
# 0                   4            8.0        101.24           Fog
# ...

# %% [markdown]
# ### 3. All the null values

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temprature_C        0
# Dew Point Temp_C    0
# Humidity_%          0
# Wind Speed_km/h     0
# Visibility_km       0
# Pressure_kPa        0
# Weather             0
# dtype: int64

# %% [markdown]
# ### 4. Renaming the columns

# %%
df.rename(columns={'Press_kPa': 'Pressure_kPa'}, inplace=True)            
df.rename(columns={'Temp_C': 'Temprature_C'}, inplace=True)
df.rename(columns={'Rel Hum_%': 'Humidity_%'}, inplace=True)
df.rename(columns={'Weather': 'Weather Condition'}, inplace=True)

# %%
df.head()
# Out:
#             Date/Time  Temprature_C  Dew Point Temp_C  Humidity_%  \
# 0 2012-01-01 00:00:00          -1.8              -3.9          86
# 1 2012-01-01 01:00:00          -1.8              -3.7          87
# 2 2012-01-01 02:00:00          -1.8              -3.4          89
# 3 2012-01-01 03:00:00          -1.5              -3.2          88
# 4 2012-01-01 04:00:00          -1.5              -3.3          88
#
#    Wind Speed_km/h  Visibility_km  Pressure_kPa     Weather Condition
# 0                4            8.0        101.24                   Fog
# 1                4            8.0        101.24                   Fog
# 2                7            4.0        101.26  Freezing Drizzle,Fog
# 3                6            4.0        101.27  Freezing Drizzle,Fog
# 4                7            4.8        101.23                   Fog

# %% [markdown]
# ###  5. All instances when 'Snow' was recoreded

# %%
df[df['Weather Condition'].str.contains('Snow')]
# Out:
#                Date/Time  Temprature_C  Dew Point Temp_C  Humidity_%  \
# 41   2012-01-02 17:00:00          -2.1              -9.5          57
# 44   2012-01-02 20:00:00          -5.6             -13.4          54
# 45   2012-01-02 21:00:00          -5.8             -12.8          58
# 47   2012-01-02 23:00:00          -7.4             -14.1          59
# 48   2012-01-03 00:00:00          -9.0             -16.0          57
# ...                  ...           ...               ...         ...
# 8779 2012-12-31 19:00:00           0.1              -2.7          81
# 8780 2012-12-31 20:00:00           0.2              -2.4          83
# 8781 2012-12-31 21:00:00          -0.5              -1.5          93
# 8782 2012-12-31 22:00:00          -0.2              -1.8          89
# 8783 2012-12-31 23:00:00           0.0              -2.1          86
#
#       Wind Speed_km/h  Visibility_km  Pressure_kPa Weather Condition
# 41                 22           25.0         99.66      Snow Showers
# ...

# %% [markdown]
# ### 6. All the instances when "Wind Speed is above 24 km/h" and "Visibility is 25 km"..

# %%
df[(df['Wind Speed_km/h'] > 24 ) & (df['Visibility_km'] == 25)]
# Out:
#                Date/Time  Temprature_C  Dew Point Temp_C  Humidity_%  \
# 23   2012-01-01 23:00:00           5.3               2.0          79
# 24   2012-01-02 00:00:00           5.2               1.5          77
# 25   2012-01-02 01:00:00           4.6               0.0          72
# 26   2012-01-02 02:00:00           3.9              -0.9          71
# 27   2012-01-02 03:00:00           3.7              -1.5          69
# ...                  ...           ...               ...         ...
# 8705 2012-12-28 17:00:00          -8.6             -12.0          76
# 8753 2012-12-30 17:00:00         -12.1             -15.8          74
# 8755 2012-12-30 19:00:00         -13.4             -16.5          77
# 8759 2012-12-30 23:00:00         -12.1             -15.1          78
# 8760 2012-12-31 00:00:00         -11.1             -14.4          77
#
#       Wind Speed_km/h  Visibility_km  Pressure_kPa Weather Condition
# 23                 30           25.0         99.31            Cloudy
# ...

# %% [markdown]
# ### 7.Mean value of each column against each "Weather Condition".

# %%
df.groupby('Weather Condition').mean()
# Out:
#                                                             Date/Time  \
# Weather Condition
# Clear                                   2012-06-25 18:03:12.760180992
# Cloudy                                  2012-07-01 16:51:29.583333376
# Drizzle                                 2012-09-17 15:00:00.000000000
# Drizzle,Fog                             2012-06-30 00:44:15.000000000
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00.000000000
# Drizzle,Snow                            2012-12-18 16:30:00.000000000
# Drizzle,Snow,Fog                        2012-12-19 20:56:00.000000000
# Fog                                     2012-06-24 21:08:00.000000000
# Freezing Drizzle                        2012-03-05 23:25:42.857142784
# Freezing Drizzle,Fog                    2012-04-30 06:20:00.000000000
# Freezing Drizzle,Haze                   2012-02-01 12:00:00.000000000
# Freezing Drizzle,Snow                   2012-06-27 12:32:43.636363520
# ...

# %% [markdown]
# ### 8. All instances when "Weather is Clear" and "Visibility is above 40"...

# %%
df[(df['Weather Condition'] == 'Clear') & (df['Visibility_km'] > 40)]
# Out:
#                Date/Time  Temprature_C  Dew Point Temp_C  Humidity_%  \
# 351  2012-01-15 15:00:00         -15.4             -22.8          53
# 352  2012-01-15 16:00:00         -15.1             -22.8          52
# 425  2012-01-18 17:00:00         -11.3             -18.8          54
# 440  2012-01-19 08:00:00         -13.7             -18.4          68
# 441  2012-01-19 09:00:00         -12.7             -17.2          69
# ...                  ...           ...               ...         ...
# 8384 2012-12-15 08:00:00         -10.7             -15.6          67
# 8385 2012-12-15 09:00:00         -10.4             -15.9          64
# 8389 2012-12-15 13:00:00          -8.4             -14.7          60
# 8631 2012-12-25 15:00:00          -7.1             -13.7          59
# 8632 2012-12-25 16:00:00          -7.5             -13.9          60
#
#       Wind Speed_km/h  Visibility_km  Pressure_kPa Weather Condition
# 351                24           48.3        102.71             Clear
# ...

# %% [markdown]
# ### 9. All instances when "Weather is Clear" and "Relative Humidity is greater than 50"...

# %%
df[(df['Weather Condition'] == 'Clear') & (df['Humidity_%'] > 50) & (df['Visibility_km'] > 40)]
# Out:
#                Date/Time  Temprature_C  Dew Point Temp_C  Humidity_%  \
# 351  2012-01-15 15:00:00         -15.4             -22.8          53
# 352  2012-01-15 16:00:00         -15.1             -22.8          52
# 425  2012-01-18 17:00:00         -11.3             -18.8          54
# 440  2012-01-19 08:00:00         -13.7             -18.4          68
# 441  2012-01-19 09:00:00         -12.7             -17.2          69
# ...                  ...           ...               ...         ...
# 8384 2012-12-15 08:00:00         -10.7             -15.6          67
# 8385 2012-12-15 09:00:00         -10.4             -15.9          64
# 8389 2012-12-15 13:00:00          -8.4             -14.7          60
# 8631 2012-12-25 15:00:00          -7.1             -13.7          59
# 8632 2012-12-25 16:00:00          -7.5             -13.9          60
#
#       Wind Speed_km/h  Visibility_km  Pressure_kPa Weather Condition
# 351                24           48.3        102.71             Clear
# ...
